# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
d1=pd.read_csv("C:\\Users\\korad\\Desktop\\seaborn\\187.tips.csv")
d1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(x='total_bill',data=d1)
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(x='total_bill',data=d1,binwidth=0.5)
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='Count'>

# %%
plt.figure(figsize=(15,6))
sns.histplot(x='total_bill',data=d1,bins=np.arange(0,55,2.5))     #for no of bars..
plt.xticks(np.arange(0,60,2.5))
# Out:
# ([<matplotlib.axis.XTick at 0x2776561bac0>,
# ...
#  [Text(0.0, 0, '0.0'),
#   Text(2.5, 0, '2.5'),
#   Text(5.0, 0, '5.0'),
#   Text(7.5, 0, '7.5'),
#   Text(10.0, 0, '10.0'),
#   Text(12.5, 0, '12.5'),
#   Text(15.0, 0, '15.0'),
#   Text(17.5, 0, '17.5'),
#   Text(20.0, 0, '20.0'),
#   Text(22.5, 0, '22.5'),
#   Text(25.0, 0, '25.0'),
#   Text(27.5, 0, '27.5'),
#   Text(30.0, 0, '30.0'),
#   Text(32.5, 0, '32.5'),
#   Text(35.0, 0, '35.0'),
#   Text(37.5, 0, '37.5'),
#   Text(40.0, 0, '40.0'),
#   Text(42.5, 0, '42.5'),
#   Text(45.0, 0, '45.0'),
#   Text(47.5, 0, '47.5'),
#   Text(50.0, 0, '50.0'),
#   Text(52.5, 0, '52.5'),
#   Text(55.0, 0, '55.0'),
#   Text(57.5, 0, '57.5')])

# %%
sns.histplot(x='total_bill',data=d1,kde=True)
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(x='total_bill',data=d1,hue='day')
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(x='total_bill',data=d1,hue='day',multiple='stack')
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(x='total_bill',data=d1,element='step')
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(x='total_bill',data=d1,hue='day',element='step',fill=False,multiple='stack')
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(x='total_bill',data=d1,hue='day',multiple='dodge')
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(x='day',data=d1,shrink=0.7)
# Out:
# <AxesSubplot: xlabel='day', ylabel='Count'>
