# %%
#heatmap plot....

import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
d1=pd.read_csv("C:\\Users\\korad\\Desktop\\seaborn\\187.tips.csv")
d1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
m = sns.FacetGrid(data=d1,col='day')
m.map_dataframe(sns.scatterplot,x='total_bill',y='tip',hue='sex')

# %%
m = sns.FacetGrid(data=d1,col='day')
m.map_dataframe(sns.histplot,x='total_bill',y='tip',hue='sex')
