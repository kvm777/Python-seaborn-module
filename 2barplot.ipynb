# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
d1 = pd.read_csv("C:\\Users\\korad\\Desktop\\seaborn\\187.tips.csv")

# %%
d2 = pd.read_excel("C:\\Users\\korad\\Desktop\\python examples\\modules\\seaborn\\Academic.xlsx")

# %%
d1.head(20)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2
# ...

# %%
d2
# Out:
#     S.No.    Roll No.                             Name  1-1 Semester  \
# 0       1  18VV1A0301                   Alaboni Amulya          7.13
# 1       2  18VV1A0302              Alam Harsha Vardhan          7.04
# 2       3  18VV1A0303             Anirudh Chandra Vuba          7.38
# 3       4  18VV1A0304                 Banka Uday Kiran          7.08
# 4       5  18VV1A0305             Biddika Santha Kumar          8.58
# ..    ...         ...                              ...           ...
# 56     57  19VV5A0377                       Pyla Ramya           NaN
# 57     58  19VV5A0378  Siva Kali Pranav Teja Surisetty           NaN
# 58     59  19VV5A0379                    Tanniru Srinu           NaN
# 59     60  19VV5A0380          Teki Chandu Durgaprasad           NaN
# 60     61  19VV5A0381                   Vangala Rohini           NaN
#
#     1-2 Semester  2-1 Semester  2-2 Semester  3-1 Semester  3-2 Semester  \
# ...

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
plt.figure(figsize=(15,4)) 
       
sns.barplot(x='Roll No.',y='Average',data=d2.head(10))
# Out:
# <AxesSubplot: xlabel='Roll No.', ylabel='Average'>

# %%
sns.barplot(x='day',y='total_bill',hue='sex',data=d1,estimator=sum)
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='total_bill',y='day',data=d1)
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='day'>

# %%
d3 = pd.read_csv("C:\\Users\\korad\\Desktop\\python examples\\modules\\pandas\\BILLIONAIRES.csv")

# %%
d3
# Out:
#     RANK                                        NAME NET WORTH   AGE  \
# 0    1.0                    Bernard Arnault & family  $176.6 B  73.0
# 1    2.0                                   Elon Musk  $146.5 B  51.0
# 2    3.0                                Gautam Adani  $116.7 B  60.0
# 3    4.0                                  Jeff Bezos  $108.5 B  58.0
# 4    5.0                              Warren Buffett  $106.3 B  92.0
# 5    6.0                                  Bill Gates  $103.5 B  67.0
# 6    7.0                               Larry Ellison  $101.4 B  78.0
# 7    8.0                               Mukesh Ambani   $87.9 B  65.0
# 8    9.0                   Carlos Slim Helu & family   $83.6 B  82.0
# 9   10.0                               Steve Ballmer   $78.2 B  66.0
# 10  11.0                                  Larry Page   $78.2 B  49.0
# 11  12.0                           Michael Bloomberg   $76.8 B  80.0
# 12  13.0                                 Sergey Brin   $75.0 B  49.0
# ...

# %%
x = d3['NAME'].sort_values().head(10)
x.unique()
# Out:
# array(['Alain Wertheimer', 'Alice Walton', 'Amancio Ortega',
#        'Andrey Melnichenko', 'Beate Heister & Karl Albrecht Jr. & family',
#        'Bernard Arnault & family', 'Bill Gates',
#        'Carlos Slim Helu & family', 'Charles Koch', 'Colin Zheng Huang'],
#       dtype=object)

# %%
plt.figure(figsize=(20,6))

sns.barplot(x='NAME',y='AGE',data=d3,order=['Alain Wertheimer', 'Alice Walton', 'Amancio Ortega',
       'Andrey Melnichenko', 'Beate Heister & Karl Albrecht Jr. & family',
       'Bernard Arnault & family', 'Bill Gates',
       'Carlos Slim Helu & family', 'Charles Koch', 'Colin Zheng Huang'])
# Out:
# <AxesSubplot: xlabel='NAME', ylabel='AGE'>
