# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
d1=pd.read_csv("C:\\Users\\korad\\Desktop\\seaborn\\187.tips.csv")
d1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
d2 = pd.read_excel("C:\\Users\\korad\\Desktop\\python examples\\modules\\seaborn\\Academic.xlsx") 
d2.head()
# Out:
#    S.No.    Roll No.                  Name  1-1 Semester  1-2 Semester  \
# 0      1  18VV1A0301        Alaboni Amulya          7.13          6.67
# 1      2  18VV1A0302   Alam Harsha Vardhan          7.04          6.25
# 2      3  18VV1A0303  Anirudh Chandra Vuba          7.38          6.92
# 3      4  18VV1A0304      Banka Uday Kiran          7.08          6.21
# 4      5  18VV1A0305  Biddika Santha Kumar          8.58          7.67
#
#    2-1 Semester  2-2 Semester  3-1 Semester  3-2 Semester  Average
# 0          6.81          6.95          7.27          7.14     6.99
# 1          6.68          6.95          7.23          7.00     6.85
# 2          7.36          6.55          7.00          7.00     7.03
# 3          6.18          6.45          7.00          7.04     6.65
# 4          7.13          7.00          7.27          7.80     7.57

# %%
d3 = pd.read_csv("C:\\Users\\korad\\Desktop\\python examples\\modules\\pandas\\BILLIONAIRES.csv")
d3.head()
# Out:
#    RANK                      NAME NET WORTH   AGE  \
# 0   1.0  Bernard Arnault & family  $176.6 B  73.0
# 1   2.0                 Elon Musk  $146.5 B  51.0
# 2   3.0              Gautam Adani  $116.7 B  60.0
# 3   4.0                Jeff Bezos  $108.5 B  58.0
# 4   5.0            Warren Buffett  $106.3 B  92.0
#
#                         SOURCE COUNTRY/TERRITORY
# 0                         LVMH            France
# 1                Tesla, SpaceX     United States
# 2  infrastructure, commodities             India
# 3                       Amazon     United States
# 4           Berkshire Hathaway     United States

# %%
sns.swarmplot(data=d1,y='total_bill',x='day',hue='sex')
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(data=d1,y='total_bill',x='day')
sns.boxplot(data=d1,y='total_bill',x='day',color='gray')
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(data=d1,y='total_bill',x='day')
sns.violinplot(data=d1,y='total_bill',x='day',color='gray')
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>
